# %% [markdown]
# # Prompt
#
# Your task is to create a baseline keylogger biometric model.
#     You will be given 120 minutes to work on it.
#
# You can use any library functions, search Google / Stack Overflow, etc.
#     Feel free also to explore the data directory with standard command tools
#
# Overview of the problem
#     Keyloggers record what keys a person presses, whether they are pressing the
#         key (downstroke) or releasing it (upstroke), and the time associated
#         with that event. For this problem, we'll be focusing on downstrokes
#         only. A small dataset of keylogger files for a few different users is
#         given in the data directory. (Taken from an open keylogger dataset.)
#     This keylogger data can be used to biometrically identify individuals by
#         the way that they type, which can be used for authentication. For
#         example, people type the word "the" differently. We can use statistics
#         on the interkey timings (e.g., the time between "t" and "h") to provide
#         a signal for identifying users. For this problem, we'll focus on
#         bigram times (time deltas involving two consecutive keys).
#     Finally, these bigram statistics can be used to classify individuals. We
#         will build a classifier from this data to predict the user from the
#         keylogger data. We'll look in particular at N-ary classification
#         models where we have training data for each of the N classes (users).
#         We will create a simple baseline model using our dataset here and
#         report train and test accuracy.
#
# The task is composed of the following 3 parts:
#     1 Parsing the data
#         1A: parse a keylogger file
#         1B: parse the directory of keylogger files
#     2 Featurizing the data
#         2A: create bigram features for a single keylogger session
#         2B: map bigrams and users to feature matrix and label vector
#     3 Evaluating a baseline classifier
#         3A: instantiate a baseline classifier
#         3B: evaluate the classifier's accuracy
#     Please run all three parts of your code and display the outputs in this notebook.
#
#
# We may discuss your code submission during a follow-up call.

# %%
#IMPORTS
import os
#import numpy as np

# %%
# PART 1: Parsing Data

# 1A
def parse_keylogger_file(path='data/22f414/26.log'):
    """
    Parse a single keylogger file, ignoring upstrokes.
        The default path points to an example keylogger file.

    Return a time-ordered list of (time, key) tuples
    """
    
    keylogger = []
    
    #YOUR CODE HERE
        
    return keylogger


# 1B
def parse_keylogger_directory(root='data'):
    
    """
    Use parse_keylogger_file to parse full directory of data and assemble in list
    """
    fulldata = []
    
    #YOUR CODE HERE
    
    return fulldata

# %%
#PART 1 OUTPUTS - USE YOUR FUNCTIONS TO PRODUCE OUTPUTS

#YOUR CODE HERE

# %%
# PART 2: Featurizing

# 2A
def generate_bigrams(keylogger):
    """
    Generate bigram timings from a single keylogger session
        keylogger = list of (time, key) tuples

    Bigrams are the time delta from one keystroke to the subsequent keystroke
        Example: the keystrokes (22, a), (89, b) map to bigram ab with time 67

    Return the bigram timings in whatever data structure is most suitable.
    """
    Bigrams = []
    
    #YOUR CODE HERE

    return Bigrams



# 2B
def featurize_data(data):
    """
    Take the parsed keylogger and create bigram features for all sessions

    In particular, generate means and standard deviations for each bigram.

    In addition, generate a label array where each user is a separate class

    Return X, y where: 
        X = 2D array of features
        y = 1D array of labels
    """
    #YOUR CODE HERE

    return X,y

# %%
#PART 2 OUTPUTS - USE YOUR FUNCTIONS TO PRODUCE OUTPUTS

#YOUR CODE HERE

# %%
# PART 3: Creating a Baseline Model

# 3A
def get_classifier():
    """
    Return a baseline classifier with fit and predict functionality:
        clf.fit(X, y)
        y_predict = clf.predict(X)
    """

    #YOUR CODE HERE
    return clf
    


# 3B
def evaluate_classifier(clf, X, y):
    """
    Evaluate the classifier clf on the X and y data.
        Use a simple 50/50 train/test split

    Return its accuracy on train and test
    """
    #YOUR CODE HERE

    
    return train_acc, test_acc

# %%
#PART 3 OUTPUTS - USE YOUR FUNCTIONS TO PRODUCE OUTPUTS

#YOUR CODE HERE
